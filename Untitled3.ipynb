# %% [markdown]
#  #string

# %%
s="welcome team"
s
# Out:
# 'welcome team'

# %%
s1="welcome taem"
s1
# Out:
# 'welcome taem'

# %%
s2='''welcome team'''
s2
# Out:
# 'welcome team'

# %%
 s3 = '''welcome to nareshit
        under prakash senapati guidence
        4pm batch'''
 s3
# Out:
# 'welcome to nareshit\n       under prakash senapati guidence\n       4pm batch'

# %% [markdown]
# string indexes

# %%
s1='welcome'
s1
# Out:
# 'welcome'

# %%
s1[0]
# Out:
# 'w'

# %%
s1[4]
# Out:
# 'o'

# %%
s1[6]
# Out:
# 'e'

# %%
s1[-7]
# Out:
# 'w'

# %%
s1
# Out:
# 'welcome'

# %%
s1[:]
# Out:
# 'welcome'

# %%
s1[1:4]
# Out:
# 'elc'

# %%
s1[1:-4]
# Out:
# 'el'

# %%
s1[3:7]
# Out:
# 'come'
