# %%
l2=[10,20,30]
l2
# Out:
# [10, 20, 30]

# %%
l2[0]=100
l2
# Out:
# [100, 20, 30]

# %%
l2.insert(2,25)
l2
# Out:
# [100, 20, 25, 25, 30]

# %% [markdown]
# l2.pop()

# %% [markdown]
# #tuple

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,True, 2.3, 1+2j, 'welcome')
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1.index(1+2j)
# Out:
# 3

# %%
t=(10,20,30)
t
# Out:
# (10, 20, 30)

# %%
t*3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)
