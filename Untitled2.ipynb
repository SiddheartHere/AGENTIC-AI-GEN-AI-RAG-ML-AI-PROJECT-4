# %%
age = 24
age
# Out:
# 24

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140717699942232

# %% [markdown]
# #float

# %%
f=110.23
f
# Out:
# 110.23

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 1972230543344

# %%
print(age)
print(f)
# Out:
# 24
# 110.23

# %% [markdown]
#  #bool

# %%
b=True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1=False
b1
# Out:
# False

# %%
type(b1)
# Out:
# bool

# %%
p = 20
q = 20

# %%
print(id(p))
print(id(p))
# Out:
# 140717699942104
# 140717699942104

# %%
print(p)
# Out:
# 20

# %%
p=p+10
p
# Out:
# 70

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
True
# Out:
# True

# %%
True+False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
False//True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c1=20+40j
c1
# Out:
# (20+40j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+40j)

# %%
c+c1
# Out:
# (30+60j)
