# %% [markdown]
# number system

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(9)
# Out:
# '0x9'

# %%
hex(10)
# Out:
# '0xa'

# %%
int(0xa)
# Out:
# 10

# %% [markdown]
# #complement

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
12 & 13
# Out:
# 12

# %%
12|13
# Out:
# 13

# %%
12^13
# Out:
# 1

# %%
13^14
# Out:
# 3

# %%
12<<2
# Out:
# 48

# %%
12<<1
# Out:
# 24

# %%
12>>2
# Out:
# 3

# %%
12>>1
# Out:
# 6
